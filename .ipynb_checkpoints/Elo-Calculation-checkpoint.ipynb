# %%
import numpy as np
import pandas as pd

# %%
class EloCalculator:
    def __init__(self, events_path, elo_path):
        self.elo_path = elo_path
        self.events = pd.read_csv('data/events_elo.csv')
        self.elo_table = pd.read_csv(self.elo_path)
        self.elo_dict = dict(zip(self.elo_table['player_id'], self.elo_table['elo_rating']))
        del(self.elo_table['elo_rating'])
        self.snapshots = []

    def calc_season_elo(self, k=2):
        self.k = k
        num_rows = self.events.shape[0]
        prev_prop = -1
        i = 0
        
        for _, row in self.events.iterrows():
            curr_prop = i/num_rows
            if (curr_prop - prev_prop) > .1:
                self.save_snapshot()
                prev_prop = curr_prop

            self.update_elo(row['bat_id'], row['pit_id'], row['batter_score'], row['pitcher_score'])
            i += 1
            
    def save_snapshot(self):
        self.snapshots.append(self.elo_dict.copy())

    def update_elo(self, bat_id, pit_id, bat_score, pit_score):
            bat_exp, pit_exp = self.get_expected(bat_id, pit_id)
            bat_curr = self.elo_dict[bat_id]
            pit_curr = self.elo_dict[pit_id]
            
            bat_new = self.calc_new(bat_curr, bat_score, bat_exp)
            pit_new = self.calc_new(pit_curr, pit_score, pit_exp)

            self.elo_dict[bat_id] = bat_new
            self.elo_dict[pit_id] = pit_new

    def get_expected(self, bat_id, pit_id):
        bat_diff = self.elo_dict[bat_id] - self.elo_dict[pit_id]
        pit_diff = -bat_diff
        return self.calc_expected(bat_diff), self.calc_expected(pit_diff)

    def calc_expected(self, diff):
        return 1/(1+(np.power(10, (diff/400))))

    def calc_new(self, curr, score, exp):
        return curr+(self.k*(score-exp))
    
    def get_dict(self):
        return self.elo_dict
    
    def get_df(self):
        list_dict = {}
        for k, v in self.elo_dict.items():
            list_dict[k] = [v]
        dfElo = pd.DataFrame.from_dict(list_dict, orient='index').reset_index()
        dfElo.columns = ['player_id', 'elo']
        return dfElo
        
    def reset_df(self):
        self.elo_table = pd.read_csv(self.elo_path)

# %%
elo = EloCalculator('data/events_elo.csv', 'data/elo.csv')
elo.calc_season_elo()

# %%
dfElo = elo.get_df()

# %%
dfElo.head()
# Out:
#   player_id          elo
# 0  zimmr001   759.860114
# 1  zimmj003  2531.972876
# 2  wertj001   959.340149
# 3  waltz001  1494.273048
# 4  tracc001  1359.538763

# %%
elo.snapshots[1]
# Out:
# {'zimmr001': 1464.7724999506077,
#  'zimmj003': 1522.8179561845584,
#  'wertj001': 1489.1096060215684,
#  'waltz001': 1495.0645891116599,
#  'tracc001': 1491.0890244580996,
#  'suzuk001': 1482.133786976087,
#  'stras001': 1520.173856036232,
#  'stord001': 1523.0285336809434,
#  'stamc001': 1527.8706753172269,
#  'spand001': 1466.927269499787,
#  'sorir001': 1513.439138816191,
#  'solaj002': 1490.7625440426093,
#  'rodrh002': 1500.7478610167661,
#  'roart001': 1531.200739264362,
#  'renda001': 1490.9791431844028,
#  'ramow001': 1478.8935481922383,
#  'peree003': 1497.0463751974523,
#  'ohler001': 1500,
#  'moort002': 1486.1268905330296,
#  'mayay001': 1500,
#  'mattr001': 1499.6923576900388,
#  'marrc001': 1500,
#  'lombs002': 1474.559985779506,
#  'leons001': 1498.74950180645,
#  'laroa001': 1473.7193626081212,
#  'kroli001': 1505.9004790505355,
#  'kobej001': 1491.5202805673687,
#  'karnn001': 1505.7051434641994,
#  'jordt001': 1507.744231988956,
#  'harpb003': 1478.2250519849183,
#  'hared001': 1542.7256685096859,
#  'hairs001': 1485.3039454713398,
#  'gonzg003': 1528.320704972151,
#  'espid001': 1484.3518073174534,
#  'dukez001': 1503.3865323901082,
#  'detwr001': 1500,
#  'desmi001': 1459.7330878573653,
#  'dejed001': 1474.2138819848678,
#  'davie002': 1504.447074109904,
#  'clipt001': 1508.011704120214,
#  'cedex001': 1502.6402008540579,
#  'browc003': 1499.7357149980546,
#  'bernr001': 1478.500107863816,
#  'abadf001': 1506.445879319394,
#  'webet001': 1500,
#  'wangc001': 1500,
#  'wagnn001': 1511.8208732481603,
#  'tholj001': 1489.842938068867,
#  'storm001': 1500,
#  'sierm001': 1492.3286794135736,
#  'sants001': 1508.49047666827,
#  'romer002': 1500,
#  'rogee002': 1525.2593246905833,
#  'reyej001': 1479.2466016633705,
#  'redmt002': 1520.612196773902,
#  'rasmc001': 1484.4279488987208,
#  'pillk001': 1494.790843637773,
#  'perel001': 1501.8631674590354,
#  'perej001': 1516.2229539545287,
#  'ortir002': 1500,
#  'olivd001': 1505.1921691190219,
#  'nolis001': 1500,
#  'nickm001': 1500,
#  'morrb001': 1500,
#  'mcgod001': 1504.4718555689503,
#  'loupa001': 1504.2661186954927,
#  'linda001': 1484.3135101669602,
#  'lincb001': 1509.506254513146,
#  'lawrb002': 1481.9887568965594,
#  'laroa002': 1500,
#  'langr002': 1500,
#  'laffa001': 1500,
#  'kawam001': 1498.3871799941394,
#  'johnj009': 1498.362463690968,
#  'jenkc001': 1500,
#  'jeffj001': 1498.4293250256399,
#  'jansc001': 1508.5596541033833,
#  'iztum001': 1484.3893967761546,
#  'happj001': 1500,
#  'gosea001': 1491.704125900928,
#  'gonze001': 1500,
#  'goinr001': 1489.247902071726,
#  'germj001': 1500,
#  'encae001': 1493.1180649826113,
#  'drabk001': 1500,
#  'dickr001': 1505.784145300713,
#  'derom001': 1491.1908514243153,
#  'delas001': 1506.2618604493323,
#  'davir003': 1488.7095380999485,
#  'cecib001': 1502.424254609398,
#  'cabrm002': 1498.4818282312788,
#  'bushd001': 1500,
#  'buehm001': 1527.2456511340147,
#  'bonie001': 1492.0998877649945,
#  'blanh001': 1491.264358483993,
#  'bautj002': 1485.7037440406166,
#  'arenj001': 1471.6360509351146,
#  'wolfr002': 1505.696191091149,
#  'tepen001': 1507.2321194390393,
#  'sotog001': 1495.0457066768158,
#  'sorij001': 1506.8854266272133,
#  'schet001': 1515.2193080668496,
#  'rossr002': 1502.102574048721,
#  'rosaa001': 1500,
#  'riosa002': 1492.2391972624243,
#  'profj001': 1478.3900355455294,
#  'piera001': 1479.4559576232432,
#  'perem004': 1523.0992879439216,
#  'ortij004': 1502.2770923025553,
#  'ogana001': 1523.1728185156883,
#  'nathj001': 1508.5979108829847,
#  'murpd005': 1477.1731565742878,
#  'morem001': 1477.406659239331,
#  'mcguc001': 1500,
#  'mcclk001': 1500,
#  'martl004': 1478.0946085419264,
#  'lowed001': 1498.3004982885575,
#  'lindj004': 1500,
#  'kirkm001': 1501.110573943907,
#  'kinsi001': 1472.5304051507267,
#  'holld003': 1519.2594140290491,
#  'harrm001': 1500,
#  'grimj002': 1500,
#  'gentc001': 1481.505761472083,
#  'garzm001': 1534.1599791025426,
#  'garcl004': 1496.2525127124836,
#  'frasj002': 1510.8512969119706,
#  'fontw001': 1500,
#  'felin001': 1502.822909542091,
#  'darvy001': 1546.3109080674844,
#  'cruzn002': 1497.5446200053216,
#  'cottn001': 1506.5650406659377,
#  'chirr001': 1500,
#  'butlj002': 1498.9847515297447,
#  'burnc001': 1500,
#  'borbj001': 1497.8060501348498,
#  'blact001': 1504.3883615521202,
#  'berkl001': 1495.5616989265325,
#  'belte002': 1494.0312962045882,
#  'belta001': 1479.0038370959273,
#  'bakej001': 1494.5892847983391,
#  'andre001': 1480.453418689367,
#  'adduj002': 1498.6133789505802,
#  'zobrb001': 1490.7697356293045,
#  'yound003': 1498.2524838037168,
#  'wrigw001': 1508.4665976943654,
#  'wrigj001': 1500.2529277472215,
#  'torra002': 1505.974260434819,
#  'scotl001': 1497.273801792176,
#  'romee002': 1500,
#  'rodrs002': 1496.2523204881559,
#  'rodnf001': 1504.4057994434827,
#  'rober002': 1495.09007703412,
#  'ramoc001': 1503.848037106734,
#  'pricd001': 1514.4908655634763,
#  'peraj002': 1506.013726657279,
#  'odorj001': 1500,
#  'myerw001': 1488.0214229230617,
#  'moorm003': 1513.3954917096974,
#  'molij001': 1491.0274621760323,
#  'mcgej001': 1503.5343249611572,
#  'luekj001': 1502.5561154645368,
#  'longe001': 1484.7345117121467,
#  'lonej001': 1486.8128753324672,
#  'lobaj001': 1494.5444362089384,
#  'kierk001': 1500,
#  'joycm001': 1487.1634708438637,
#  'johnk003': 1489.7408800189746,
#  'jennd002': 1499.5888605069658,
#  'carmf001': 1512.794656764981,
#  'hellj001': 1520.2132804894384,
#  'guzmf001': 1500,
#  'gomeb001': 1500.045003595697,
#  'gimec001': 1498.9967769751192,
#  'fulds001': 1502.408983347458,
#  'farnk001': 1502.973891069375,
#  'escoy001': 1483.7260648799934,
#  'duncs001': 1500,
#  'coloa001': 1500,
#  'cobba001': 1500,
#  'bourj001': 1497.5839792562738,
#  'belij001': 1500,
#  'beckt001': 1500,
#  'archc001': 1508.1141055692196,
#  'wongk001': 1500,
#  'wiggt001': 1496.9524100336014,
#  'westj001': 1500,
#  'waina001': 1540.5913115428305,
#  'wachm001': 1500,
#  'siegk001': 1503.7682075573912,
#  'salaf001': 1502.1678520665007,
#  'rzepm001': 1515.745778014602,
#  'roset001': 1506.1153610382423,
#  'robis001': 1496.3969464745894,
#  'peteb002': 1500,
#  'perea002': 1500,
#  'mujie001': 1506.962252127834,
#  'moliy001': 1487.2090844888696,
#  'mills001': 1530.7593335599258,
#  'martc006': 1500,
#  'martv002': 1500,
#  'manes001': 1499.677622491479,
#  'lyont001': 1500,
#  'lynnl001': 1512.8565790814362,
#  'kozmp001': 1479.5535664013732,
#  'kellj001': 1513.4030764364368,
#  'johnr009': 1500,
#  'jay-j001': 1480.5508910942597,
#  'jackr005': 1498.9842732763555,
#  'hollm001': 1483.6386265233893,
#  'gastj001': 1500,
#  'garcj004': 1509.4202251364432,
#  'freed001': 1483.6012825226398,
#  'frees001': 1500,
#  'descd001': 1487.169788217147,
#  'curtj002': 1500,
#  'cruzt002': 1497.8193530959998,
#  'craia001': 1477.8777787189558,
#  'cletm001': 1500,
#  'choar001': 1502.920165766804,
#  'chama002': 1500,
#  'carpm002': 1465.503929916259,
#  'butlk001': 1504.8865380065422,
#  'boggm001': 1508.959053524228,
#  'blazm001': 1507.5626484802372,
#  'beltc001': 1478.4471756368782,
#  'axfoj001': 1501.915359798176,
#  'adamm002': 1487.0766228272325,
#  'zitob001': 1500,
#  'voger001': 1510.332637715812,
#  'torra001': 1477.1798082051112,
#  'tanak001': 1500,
#  'surke001': 1500,
#  'scutm001': 1493.3537084294196,
#  'sandp001': 1489.9293747689062,
#  'sanch002': 1492.9638124600826,
#  'rosas001': 1508.0288705287635,
#  'romos001': 1510.9048827016254,
#  'ramir003': 1500.6732212507102,
#  'quirg001': 1494.8999907115694,
#  'poseb001': 1479.0782905225003,
#  'pillb001': 1493.5447083418637,
#  'petiy001': 1512.2697063064845,
#  'perej002': 1495.7802609671169,
#  'pench001': 1477.9104147135972,
#  'peguf001': 1500,
#  'pagaa001': 1491.6103066837165,
#  'noonn001': 1493.68418206822,
#  'monej001': 1500,
#  'moscg001': 1500,
#  'mijaj001': 1509.2258275998345,
#  'machj002': 1513.8786791922232,
#  'lopej002': 1508.96187943106,
#  'linct001': 1525.9144568607103,
#  'kontg001': 1503.3455988484677,
#  'kiesr001': 1495.5316387894268,
#  'kickm001': 1503.7281354602724,
#  'hembh001': 1500,
#  'gillc002': 1491.3682603764482,
#  'gaudc001': 1519.2019340320085,
#  'franj004': 1493.0932749223273,
#  'crawb001': 1474.0112251922037,
#  'garcj002': 1509.0804964207807,
#  'dunnj001': 1502.4316211773325,
#  'cainm001': 1518.3629174865837,
#  'bumgm001': 1543.067761005234,
#  'blang001': 1477.4244670761798,
#  'beltb001': 1474.9334968847402,
#  'ariaj001': 1480.740266597386,
#  'affej001': 1507.1590828810456,
#  'adrie001': 1500,
#  'abret001': 1488.1984348383949,
#  'zunim001': 1483.0892557776385,
#  'wilht001': 1508.4209898205481,
#  'walkt004': 1500,
#  'triuc001': 1489.8001221852803,
#  'sucrj001': 1500,
#  'smoaj001': 1467.3289201109942,
#  'shopk001': 1493.0237345752805,
#  'seagk001': 1478.402428976365,
#  'saunm001': 1480.6587984569155,
#  'saunj001': 1540.8577798619035,
#  'ryanb002': 1494.6089985101182,
#  'ruffc001': 1500.9180581929193,
#  'ramie004': 1516.284329809559,
#  'quinh001': 1500,
#  'pryos001': 1500,
#  'pereo002': 1509.4988818502836,
#  'peguc001': 1500,
#  'paxtj001': 1500,
#  'noesh001': 1500,
#  'morsm001': 1487.2104192581585,
#  'morak001': 1471.339795279129,
#  'montj003': 1500,
#  'millb002': 1500.9369633294903,
#  'mediy001': 1507.0659788686658,
#  'maurb001': 1495.547731124896,
#  'luetl001': 1507.6229139316436,
#  'loe-k001': 1511.8857708147814,
#  'lidda001': 1498.9383662507737,
#  'lafrb001': 1502.6800390002797,
#  'iwakh001': 1500,
#  'ibanr001': 1484.6632589161436,
#  'hernf002': 1518.653910979353,
#  'haraa001': 1510.7647904577889,
#  'gutif001': 1490.012144885953,
#  'furbc001': 1510.580358525126,
#  'frann001': 1484.8309536713186,
#  'farqd001': 1508.012428907234,
#  'chave002': 1486.1272263353576,
#  'cappc001': 1505.1128809591844,
#  'bondj001': 1508.60531455216,
#  'beavb001': 1500,
#  'bay-j001': 1494.0837213257741,
#  'bantb001': 1500,
#  'andir001': 1496.0150910045852,
#  'almoa001': 1492.4391648639985,
#  'ackld001': 1490.3823303350741,
#  'volqe001': 1500,
#  'vincn001': 1509.7195312201914,
#  'venaw001': 1483.4388860780823,
#  'thayd001': 1500.3280943956347,
#  'thatj001': 1507.5957388795612,
#  'stule002': 1516.7216234248156,
#  'streh001': 1513.3528974336718,
#  'staut001': 1516.627958566929,
#  'smitb005': 1517.5787673135058,
#  'rosst001': 1534.8783345190898,
#  'robic002': 1500,
#  'river003': 1495.0897535439747,
#  'richc002': 1500,
#  'ransc001': 1487.289615315181,
#  'quenc001': 1494.6196519380799,
#  'osuls001': 1500,
#  'mikom001': 1500,
#  'medit001': 1491.458402109805,
#  'maybc001': 1500,
#  'marqj001': 1497.0786787742354,
#  'laynt001': 1501.787094601975,
#  'kotsm001': 1491.1609936428308,
#  'kenni001': 1604.9894281996642,
#  'hynec001': 1503.2030947949854,
#  'hundn001': 1469.2254915870096,
#  'headc001': 1476.9405425409711,
#  'gyorj001': 1452.9389331571836,
#  'guzmj005': 1485.918398787826,
#  'gregl001': 1505.840729466564,
#  'grany001': 1500,
#  'fuenr001': 1493.3871663238745,
#  'forsl001': 1484.0615991646357,
#  'erlir001': 1524.229425520077,
#  'denoc001': 1470.659593210504,
#  'deckj001': 1500,
#  'cirip001': 1500,
#  'ceder002': 1475.2915115735145,
#  'casha001': 1523.9658767284477,
#  'cabre001': 1484.0459279248466,
#  'bracb001': 1501.5725742997058,
#  'boxbb001': 1501.3033976994475,
#  'blank002': 1489.777058777301,
#  'bassa001': 1506.1764068818616,
#  'bakej002': 1500,
#  'amara001': 1487.9000938761762,
#  'alony001': 1479.8503390188564,
#  'zagum001': 1501.9602138437576,
#  'wilsj004': 1509.3044965275496,
#  'welkd001': 1503.428646665854,
#  'watst001': 1503.9736116081094,
#  'walkn001': 1487.8239381929686,
#  'tabaj002': 1496.951103977937,
#  'snidt001': 1484.0763649937692,
#  'sanct001': 1498.3338431864283,
#  'sancj002': 1496.2341535578628,
#  'sancg001': 1490.7815863399514,
#  'rodrw002': 1502.6399939067064,
#  'reidr001': 1510.1485854182783,
#  'presa001': 1500,
#  'pimes001': 1500,
#  'pie-f001': 1500,
#  'mortc002': 1512.6336439157976,
#  'morrb002': 1509.0152809431236,
#  'mornj001': 1491.6939987392834,
#  'mercj002': 1489.0479811582286,
#  'melam001': 1508.3116602565829,
#  'mckem001': 1491.4597121795664,
#  'mcdoj003': 1497.913982760827,
#  'mcdoj004': 1504.384308127942,
#  'mccua001': 1485.9470315799558,
#  'mazzv001': 1504.4772172394382,
#  'marts002': 1477.61827871052,
#  'martr004': 1480.5119038403905,
#  'lockj001': 1509.1104188609875,
#  'lirif001': 1513.6001781487705,
#  'leroc001': 1500.0643792835237,
#  'lamba001': 1500,
#  'joneg002': 1477.8436043406607,
#  'johnk004': 1500,
#  'irwip001': 1500,
#  'ingeb001': 1498.6804155362388,
#  'hughj001': 1510.4618858866324,
#  'harrj002': 1496.8901180114835,
#  'grilj001': 1509.5262046450164,
#  'gomej002': 1500.055100244897,
#  'cumpb001': 1500,
#  'contj002': 1500,
#  'coleg001': 1517.7000826789945,
#  'byrdm001': 1482.3314391711483,
#  'burna001': 1505.2626366984753,
#  'buckj001': 1481.7321395473057,
#  'blacv001': 1505.2756093911944,
#  'barmc001': 1481.43235326161,
#  'alvap001': 1485.6660566963262,
#  'younm003': 1477.3068272104897,
#  'wellc001': 1490.6699402748993,
#  'valdr002': 1508.771341683935,
#  'utlec001': 1482.1960019510782,
#  'susds001': 1500,
#  'stutm001': 1503.248226310196,
#  'savej001': 1506.0137639840216,
#  'ruppc001': 1497.1448180677903,
#  'ruizc001': 1488.5732089944133,
#  'ruf-d001': 1477.0229299388013,
#  'roseb003': 1504.6654416052424,
#  'rollj001': 1460.6187573003558,
#  'roblm001': 1508.5013979906537,
#  'reveb001': 1486.2430988929575,
#  'ramij002': 1503.2296855000448,
#  'pettj001': 1500,
#  'papej001': 1510.6891408942956,
#  'orr-p001': 1500.953566997357,
#  'nix-l001': 1492.5772969609927,
#  'minez001': 1504.442327303144,
#  'maybj001': 1479.5929094571197,
#  'martm003': 1496.7417166172613,
#  'marte002': 1512.8309816382132,
#  'lerus001': 1500,
#  'lee-c003': 1558.86527529837,
#  'lannj001': 1499.0968273150083,
#  'krate001': 1483.3885351034683,
#  'kendk001': 1513.1116360547628,
#  'jimec002': 1503.9897993927646,
#  'howar001': 1472.1522178761343,
#  'horsj001': 1509.7537474347391,
#  'hernc005': 1486.2367793993915,
#  'hamec001': 1541.2769718461955,
#  'hallr001': 1499.2636677095547,
#  'garcl005': 1508.5554184852617,
#  'galvf001': 1490.3212724646035,
#  'frank001': 1489.6787065797582,
#  'durbc001': 1497.0192131711347,
#  'diekj001': 1501.308242730746,
#  'defrj001': 1508.2909945745355,
#  'cloyt001': 1507.380470799707,
#  'carre001': 1500,
#  'browd004': 1473.2798753776012,
#  'basta001': 1502.667047319242,
#  'aumop001': 1502.2189119984494,
#  'aschc001': 1476.1334181626303,
#  'adamm001': 1503.2310495557279,
#  'younc004': 1473.385560095488,
#  'weekj001': 1500,
#  'vogts001': 1494.1431964539595,
#  'taylm001': 1500,
#  'strad003': 1535.1936609671764,
#  'sogae001': 1489.9448695656881,
#  'smits002': 1493.5903733769815,
#  'sizes001': 1498.0002175994546,
#  'scrie001': 1504.0650570920645,
#  'resoc001': 1506.1280471340915,
#  'reddj001': 1484.2170843456188,
#  'petes002': 1500,
#  'parra001': 1495.949007007924,
#  'parkj001': 1494.8676608753722,
#  'oterd001': 1500,
#  'okajh001': 1500,
#  'norrd001': 1496.0062797243093,
#  'neshp001': 1504.2672909593523,
#  'mossb001': 1493.051454501451,
#  'montl002': 1500,
#  'milot001': 1521.2930745019087,
#  'lowrj001': 1473.0754167418634,
#  'jasoj001': 1493.2019885023606,
#  'grifa002': 1548.0345736422596,
#  'greeg002': 1470.5285370118079,
#  'frein001': 1495.6896803382588,
#  'figup001': 1501.5078997848318,
#  'dools001': 1509.0287388682366,
#  'donaj001': 1475.8189995669168,
#  'grays001': 1505.6936460550312,
#  'crisc001': 1473.3820358972355,
#  'cookr001': 1506.7523727371577,
#  'colob001': 1529.149459919722,
#  'choim001': 1500,
#  'chavj001': 1506.6169492137055,
#  'cespy001': 1492.040986139532,
#  'calla001': 1403.0832984103654,
#  'blevj001': 1508.5915842762927,
#  'bartd001': 1492.7946642849884,
#  'balfg001': 1503.575620307064,
#  'andeb004': 1502.065535228027,
#  'youne003': 1465.3219931083831,
#  'wrigd002': 1487.2720332874562,
#  'wheez001': 1521.6337956170883,
#  'valdj002': 1498.219536087465,
#  'turnj001': 1487.8762522040697,
#  'tovaw001': 1500,
#  'torrc001': 1522.8388578798583,
#  'tejar001': 1492.8684615412594,
#  'satij001': 1491.7208729362512,
#  'rices001': 1507.3285301930891,
#  'recka001': 1495.670179064746,
#  'quino001': 1476.1161061157861,
#  'parnb001': 1508.5770493172543,
#  'nieuk001': 1494.1271196585644,
#  'niesj001': 1515.1106094406298,
#  'murpd006': 1456.033125811219,
#  'mejij001': 1500,
#  'mchuc001': 1500,
#  'matsd001': 1505.4082525344375,
#  'marcs001': 1505.6090223244987,
#  'lyonb003': 1506.195330256772,
#  'lutzz001': 1500.6466883308212,
#  'lagaj001': 1471.8195579654343,
#  'hefnj001': 1504.5396162218162,
#  'henns001': 1500,
#  'hawkl001': 1523.4669593123904,
#  'harvm001': 1513.1265371792103,
#  'germg001': 1502.3216161797363,
#  'gee-d001': 1545.5622490560716,
#  'franf001': 1500,
#  'florw001': 1491.7063546697188,
#  'felip002': 1501.9388784935668,
#  'famij001': 1505.4903187831876,
#  'edgij001': 1502.650342687511,
#  'dudal001': 1490.9317523455095,
#  'dendm001': 1493.795382668055,
#  'davii001': 1501.2538432656163,
#  'darnt001': 1490.7848992081606,
#  'cowgc001': 1482.3301730733983,
#  'centj001': 1500,
#  'carsr001': 1498.1005105852596,
#  'byrdt001': 1503.9855111276397,
#  'burkg001': 1500,
#  'browa003': 1491.6572476767824,
#  'baxtm001': 1498.2007110191746,
#  'atchs001': 1504.6983773795753,
#  'ankir001': 1499.0207685259113,
#  'aardd001': 1507.0555284875204,
#  'youkk001': 1500,
#  'wellv001': 1494.6815806762506,
#  'warra001': 1500,
#  'teixm001': 1498.0281387774094,
#  'suzui001': 1498.0133524220835,
#  'stewc001': 1497.114566442117,
#  'soria001': 1484.805611087679,
#  'sabac001': 1518.2267417802498,
#  'romia002': 1496.1973944172103,
#  'rodra001': 1500,
#  'robed002': 1499.3697906887307,
#  'rivem002': 1498.6204960493722,
#  'reynm001': 1500,
#  'pheld001': 1508.7865516862043,
#  'petta001': 1513.5967665079684,
#  'overl001': 1493.056818576294,
#  'nunov001': 1500,
#  'nunee002': 1500,
#  'novai001': 1500,
#  'nix-j001': 1496.0940750139448,
#  'nelsc001': 1461.9731282245893,
#  'nealt001': 1496.5454626775684,
#  'murpj001': 1500,
#  'millj005': 1500,
#  'mesam001': 1500,
#  'marsb001': 1500,
#  'logab001': 1500,
#  'lillb001': 1497.928329444816,
#  'kuroh001': 1500,
#  'kells001': 1500.9702342905566,
#  'josec001': 1500,
#  'jeted001': 1500,
#  'ishit001': 1500,
#  'hughp001': 1500,
#  'huffd001': 1500,
#  'hafnt001': 1498.3667686723197,
#  'granc001': 1500,
#  'gonza005': 1494.546933994031,
#  'gardb001': 1494.091914571167,
#  'franb001': 1500,
#  'epplc001': 1500,
#  'dalem002': 1500,
#  'cruzl001': 1489.9761875969605,
#  'claip001': 1500,
#  'chamj002': 1500.8965090786487,
#  'cervf001': 1500,
#  'canor001': 1491.0968628283795,
#  'cabrc001': 1500,
#  'brigr001': 1485.7713311181383,
#  'bootc001': 1498.8405509058719,
#  'boesb001': 1500,
#  'betad001': 1500,
#  'almoz001': 1500,
#  'adamd001': 1494.9165201514115,
#  'worlv001': 1499.5002452959272,
#  'waltp001': 1500,
#  'willj004': 1495.9379484492727,
#  'tonkm001': 1500,
#  'thomc002': 1495.4310488746896,
#  'thiec001': 1509.9979111471237,
#  'swara001': 1514.8072676679499,
#  'roenj001': 1505.1479914281936,
#  'robet001': 1501.1157944289005,
#  'ramiw001': 1496.7403496514119,
#  'presr001': 1510.0312758918324,
#  'plout001': 1488.2724662133446,
#  'pintj001': 1500,
#  'perkg001': 1503.790779030877,
#  'pelfm001': 1515.6222883398805,
#  'parmc001': 1496.2938701989983,
#  'mauej001': 1488.4660980445385,
#  'mastd002': 1500,
#  'marts001': 1500,
#  'hicka001': 1480.2476443147511,
#  'herrc001': 1495.1116196309226,
#  'hernp001': 1500,
#  'hendl001': 1506.6231199253054,
#  'gibsk002': 1516.5207583104566,
#  'fryee001': 1500,
#  'florp001': 1487.1856107937472,
#  'fienc001': 1504.680266056557,
#  'escoe001': 1494.0970702590853,
#  'duenb001': 1501.7028818683752,
#  'dozib001': 1483.1008414077128,
#  'doumr001': 1489.497928450448,
#  'diams001': 1500,
#  'devrc001': 1500,
#  'dedus001': 1517.156024760044,
#  'corrk001': 1502.1357802091732,
#  'colac001': 1485.1300954794874,
#  'carrj001': 1491.5387794717424,
#  'buted001': 1500,
#  'burtj001': 1505.9329592142792,
#  'bernd001': 1494.784661035243,
#  'arcio001': 1498.8394951180637,
#  'albea001': 1500,
#  'wootr001': 1501.480129651345,
#  'weekr001': 1493.8703377255263,
#  'thort001': 1513.8185236478807,
#  'seguj002': 1497.5102070422893,
#  'schal001': 1488.3981417919217,
#  'rodrf003': 1509.074663145311,
#  'ramia001': 1495.4004494638555,
#  'prinj001': 1500,
#  'peraw001': 1509.9150135543393,
#  'nelsj004': 1500,
#  'narvc001': 1500,
#  'maldm001': 1493.400636170476,
#  'lucrj001': 1487.0233338532087,
#  'lohsk001': 1550.022487466826,
#  'lallb001': 1500,
#  'kintb001': 1507.1938602960083,
#  'hendj001': 1501.350075481005,
#  'hellj002': 1500,
#  'handd001': 1505.1592054519213,
#  'halts002': 1484.94378398599,
#  'gorzt001': 1512.5772465004868,
#  'gonzm001': 1503.5922732505664,
#  'gonza002': 1500,
#  'gomec002': 1475.4094234765728,
#  'gindc001': 1493.1169203340387,
#  'genns001': 1496.9937432141303,
#  'gally001': 1513.1665040986427,
#  'franj005': 1475.7792601910817,
#  'figaa001': 1500,
#  'fierm001': 1500,
#  'estrm001': 1520.600350211978,
#  'davik003': 1488.3650782778166,
#  'burgh001': 1500,
#  'braur002': 1500,
#  'bianj001': 1483.6976932987147,
#  'betay001': 1483.619045743364,
#  'badeb001': 1500,
#  'aokin001': 1476.4734953724396,
#  'yelic001': 1487.412212153737,
#  'webbr001': 1503.7383749197418,
#  'velag002': 1500,
#  'valac001': 1500,
#  'turnj002': 1532.4134268998544,
#  'stanm004': 1466.9530946923014,
#  'solad001': 1478.612692792469,
#  'slowk001': 1501.071009845939,
#  'skipk001': 1500,
#  'sanaa001': 1500,
#  'ruggj001': 1479.4926421121174,
#  'raucj001': 1500,
#  'ramoa001': 1519.4676242569562,
#  'qualc001': 1506.9773964565534,
#  'polap001': 1465.53204909601,
#  'pierj002': 1487.8570251585486,
#  'philz001': 1500,
#  'olivm001': 1500,
#  'ozunm001': 1477.6972328804568,
#  'olmoe001': 1500,
#  'nolar001': 1555.9009040759797,
#  'morrl001': 1487.4402208711874,
#  'mathj001': 1479.8736116200932,
#  'marij002': 1487.5859803833966,
#  'mainj001': 1500,
#  'mahoj001': 1500,
#  'lucae001': 1467.5644571505998,
#  'leblw001': 1500,
#  'kotcc001': 1500,
#  'koeht001': 1508.4130154807972,
#  'keara001': 1500,
#  'jennd003': 1511.966724247805,
#  'hillk002': 1491.5171704339425,
#  'hecha001': 1464.2659922898677,
#  'hatcc002': 1500,
#  'handb001': 1500,
#  'green001': 1500,
#  'flynb001': 1500,
#  'fernj003': 1534.2739553587558,
#  'eovan001': 1556.2909838958838,
#  'dysos001': 1500,
#  'dunnm002': 1506.78734305979,
#  'dobbg001': 1497.8587064118954,
#  'dietd001': 1487.30702218898,
#  'diazm003': 1500,
#  'coghc001': 1498.7242588909492,
#  'cishs001': 1516.4787055044737,
#  'camia001': 1500,
#  'browj006': 1497.7164422174496,
#  'branr002': 1495.9904058242482,
#  'belod001': 1500,
#  'amess001': 1500.999899978899,
#  'alvah001': 1524.316126496831,
#  'withc001': 1506.2878254191598,
#  'wilsb001': 1512.0654999994313,
#  'wallj002': 1500,
#  'vanss001': 1487.1604626587973,
#  'uribj002': 1470.586073090632,
#  'tolls002': 1498.055730008216,
#  'sellj002': 1496.7901899854842,
#  'schus001': 1480.162252500369,
#  'ryu-h001': 1559.7768004692796,
#  'rodrp001': 1509.2982189003953,
#  'ramih003': 1493.683065633607,
#  'puntn001': 1479.522197132487,
#  'puigy001': 1474.5134464833347,
#  'moylp001': 1500.6561590426875,
#  'marmc001': 1501.883035516712,
#  'magim001': 1503.6739748724983,
#  'lillt001': 1511.571966772226,
#  'leagb001': 1511.187190756414,
#  'kersc001': 1529.8792795552813,
#  'kempm001': 1467.5529641095895,
#  'jansk001': 1514.5277168621442,
#  'howej003': 1522.6520896169034,
#  'herre001': 1500,
#  'hernr002': 1500.094103703969,
#  'hairj002': 1480.356046482057,
#  'guerm001': 1503.9058196589506,
#  'guerj002': 1500.3836616344463,
#  'greiz001': 1558.3739640710728,
#  'gordd002': 1493.9421000021935,
#  'gonza003': 1468.1619349960067,
#  'garco001': 1500,
#  'fifes001': 1496.8487607156292,
#  'fedet001': 1492.0098613705577,
#  'ethia001': 1481.8254502045995,
#  'ellim001': 1456.8124413195,
#  'ellia001': 1471.5980554108467,
#  'domij002': 1505.0808069918949,
#  'crawc002': 1451.3227156011321,
#  'casta003': 1500,
#  'capuc001': 1524.4195364882867,
#  'bussn001': 1493.3048079463613,
#  'billc001': 1500,
#  'belir001': 1512.2084142554054,
#  'beckj002': 1517.4675518035556,
#  'venty001': 1500,
#  'tejam001': 1498.579327744528,
#  'teafe001': 1500,
#  'smitw002': 1500,
#  'shiej002': 1500,
#  'sante001': 1500,
#  'peres002': 1493.580424805078,
#  'penac001': 1490.4793220212907,
#  'mousm001': 1483.2199246190462,
#  'moora001': 1500,
#  'mendl001': 1514.1867565105188,
#  'maxwj002': 1491.6815183256956,
#  'lougd001': 1500,
#  'kottg001': 1498.9942350755218,
#  'josed001': 1500,
#  'johne002': 1470.389968225305,
#  'hosme001': 1484.7455245328097,
#  'hollg001': 1506.3408409995604,
#  'hochl001': 1506.6883956363752,
#  'herrk001': 1503.2995317755822,
#  'hayeb001': 1500,
#  'gutij002': 1520.9932975635,
#  'guthj001': 1521.158564820872,
#  'gorda001': 1493.5937149672998,
#  'giavj001': 1500,
#  'getzc001': 1489.3375119894586,
#  'falui001': 1500,
#  'escoa003': 1489.4149272548236,
#  'dysoj001': 1495.4657676330894,
#  'dwyec001': 1500,
#  'duffd001': 1500,
#  'daviw001': 1517.5129253790737,
#  'crowa001': 1501.5851577741532,
#  'collt001': 1500.0620601518483,
#  'colel001': 1500,
#  'chenb001': 1500,
#  'cainl001': 1499.675607308474,
#  'butlb003': 1497.9277943732536,
#  'buenf001': 1500,
#  'zeidj001': 1504.7418765950565,
#  'wallb001': 1492.6579019385656,
#  'villj001': 1494.2127010106574,
#  'veraj001': 1505.3291962722474,
#  'stasm001': 1500,
#  'peacb001': 1517.597032027604,
#  'parej002': 1491.0508513744885,
#  'norrb001': 1528.267926786302,
#  'martj006': 1485.4359560024373,
#  'martf002': 1500,
#  'martd005': 1500,
#  'lylej001': 1517.951707882259,
#  'lairb001': 1500,
#  'keucd001': 1519.167438204742,
#  'humbp001': 1520.9485539949842,
#  'pagnm001': 1500,
#  'oberb001': 1514.7853792509643,
#  'lo--c001': 1502.587446030192,
#  'kraum001': 1500,
#  'hoesl001': 1500.0412120631386,
#  'harrl002': 1509.8355172670513,
#  'grosr001': 1492.184162126367,
#  'gonzm002': 1486.4122319285177,
#  'fielj002': 1502.8227687117474,
#  'elmoj001': 1498.083338853382,
#  'domim001': 1484.1547153434078,
#  'delej002': 1500,
#  'cruzr001': 1500.2092846789667,
#  'crowt001': 1500.8053228598294,
#  'cosaj001': 1500,
#  'corpc001': 1491.9246549942875,
#  'clemp002': 1499.5963573018603,
#  'clarc001': 1500,
#  'cisnj001': 1504.96084059463,
#  'chapk002': 1503.8726646112248,
#  'castj006': 1472.9592396487228,
#  'cartc002': 1487.1560649642204,
#  'bedae001': 1517.2849330984816,
#  'barnb002': 1474.389840065737,
#  'ambrh001': 1505.5452330590076,
#  'altuj001': 1473.6073354794985,
#  'wortd001': 1500,
#  'villb002': 1502.1503387865446,
#  'verlj001': 1500,
#  'valvj001': 1500,
#  'tuiam001': 1494.7380283606083,
#  'smyld001': 1513.746323671934,
#  'schem001': 1500,
#  'santr002': 1494.9453462870886,
#  'sanca004': 1508.9713490288102,
#  'reede002': 1500,
#  'rondb001': 1500,
#  'putkl001': 1500,
#  'porcr001': 1491.149354187578,
#  'pereh001': 1500,
#  'peraj001': 1494.4637751563473,
#  'penab002': 1495.718389228728,
#  'ortej001': 1500,
#  'martv001': 1489.4069515717742,
#  'kelld001': 1499.9820443346418,
#  'jacka001': 1488.2666994255785,
#  'infao001': 1494.5446586815438,
#  'iglej001': 1492.1215605404402,
#  'huntt001': 1497.4989556813891,
#  'holab001': 1500,
#  'garca003': 1500,
#  'fistd001': 1511.213365968432,
#  'fielp001': 1495.4163303557864,
#  'downd001': 1501.0310833491908,
#  'doteo001': 1497.15156680539,
#  'dirka001': 1495.7178716773772,
#  'cokep001': 1505.2956353225977,
#  'castn001': 1500,
#  'cabrm001': 1503.5834912169748,
#  'benoj001': 1502.1993297298702,
#  'avila001': 1498.7916185681117,
#  'alvaj003': 1500,
#  'albua001': 1506.175135311278,
#  'wheer001': 1488.8069818363058,
#  'volsc001': 1500,
#  'tulot001': 1480.1032027589038,
#  'torry001': 1486.102875029217,
#  'scahr001': 1503.420453502189,
#  'rutlj001': 1476.4717299154756,
#  'rosaw001': 1480.3710646851346,
#  'pomed001': 1501.8094509955356,
#  'pachj001': 1487.2719692294654,
#  'outmj001': 1518.8402945736443,
#  'ottaa001': 1517.5812317400255,
#  'oswar001': 1509.4031491053197,
#  'nicaj001': 1512.3409544366136,
#  'mansj001': 1504.3116599098014,
#  'lopew001': 1522.9965652680858,
#  'lemad001': 1475.342690622698,
#  'kensl001': 1500,
#  'herrj002': 1492.7050609330117,
#  'heltt001': 1480.1345846932315,
#  'gonzc001': 1488.600057621832,
#  'garlj001': 1504.9124542833904,
#  'franj003': 1512.0991238769918,
#  'fowld001': 1490.7523020589067,
#  'escae001': 1503.1196150931794,
#  'dickc002': 1480.9741322096609,
#  'delaj001': 1520.0865580407306,
#  'culbc001': 1489.2407065702891,
#  'cuddm001': 1474.4837861067108,
#  'corpm001': 1517.0575413250176,
#  'colvt001': 1492.3932187424516,
#  'chatt001': 1497.7510177848592,
#  'chacj001': 1503.7972797981313,
#  'brotr001': 1505.52846924961,
#  'blacc001': 1487.3841292420766,
#  'bettc001': 1510.5292840832105,
#  'betar001': 1503.0941107822632,
#  'belim001': 1509.1495273493617,
#  'arenn001': 1473.669982385711,
#  'woodb004': 1500,
#  'tomlj001': 1500,
#  'swisn001': 1476.5878933722845,
#  'stubd001': 1487.6713151736255,
#  'smitj002': 1505.887661242084,
#  'shawb001': 1510.1996588425231,
#  'santo001': 1500,
#  'santc002': 1486.9776375217627,
#  'salad001': 1523.7258314848866,
#  'rapac001': 1500,
#  'ramij003': 1500,
#  'rabur001': 1500,
#  'phelc001': 1500,
#  'pestv001': 1500,
#  'perec002': 1507.9169006261643,
#  'myerb001': 1500,
#  'mcalz001': 1514.1968065333394,
#  'mastj001': 1530.630764448464,
#  'martj004': 1500,
#  'marsl001': 1500,
#  'lee-c004': 1500,
#  'langm002': 1504.5789258317577,
#  'kubej002': 1428.2488914297892,
#  'klubc001': 1500,
#  'kipnj001': 1475.9057171470665,
#  'kazms001': 1500,
#  'jimeu001': 1514.127080528844,
#  'hillr001': 1504.228487329126,
#  'hagan001': 1500,
#  'guilp001': 1500,
#  'gomey001': 1491.8791364570795,
#  'giamj001': 1491.9409649923687,
#  'chisl001': 1491.798507553512,
#  'carsm001': 1498.849420298075,
#  'carrc003': 1512.5876177566472,
#  'cabra002': 1488.555763855267,
#  'branm003': 1472.9737252710095,
#  'bourm001': 1479.394839828262,
#  'bauet001': 1500,
#  'barns002': 1500,
#  'avilm001': 1482.7895003962335,
#  'allec002': 1508.2595986533793,
#  'albem001': 1502.7983577985376,
#  'vottj001': 1491.8666215504086,
#  'villp001': 1500,
#  'soton001': 1500,
#  'simoa001': 1511.20315784138,
#  'rodrh003': 1500,
#  'robid002': 1486.12905506203,
#  'reyng001': 1500,
#  'philb001': 1481.6067093144663,
#  'paulx001': 1494.5448565089407,
#  'partc001': 1498.9396294608493,
#  'parrm001': 1506.7479549603154,
#  'ondrl001': 1510.646455446301,
#  'millc001': 1495.6122859350921,
#  'mesod001': 1486.690087297293,
#  'marss002': 1500,
#  'lutzd001': 1497.8939682635164,
#  'ludwr001': 1500,
#  'lecus001': 1505.5860720645767,
#  'leakm001': 1519.6241023796542,
#  'latom001': 1520.7312533539155,
#  'iztuc001': 1497.50950833843,
#  'hoovj002': 1503.454457712838,
#  'heisc001': 1493.1510467138748,
#  ...}

# %%
dfBat = pd.read_csv('data/batters.csv')
dfPit = pd.read_csv('data/pitchers.csv')

dfBat = pd.merge(dfElo, dfBat, left_on='player_id', right_on='player_id')
dfBat = pd.merge(elo.elo_table, dfBat, left_on=['player_id', 'last_name_tx', 'first_name_tx'],
                 right_on=['player_id', 'nameLast', 'nameFirst'])

dfPit = pd.merge(dfElo, dfPit, left_on='player_id', right_on='player_id')
dfPit = pd.merge(elo.elo_table, dfPit, left_on=['player_id', 'last_name_tx', 'first_name_tx'],
                 right_on=['player_id', 'nameLast', 'nameFirst'])

dfBat = dfBat.drop_duplicates(subset=['player_id', 'C'])
dfPit = dfPit.drop_duplicates(subset=['player_id', 'C'])

dfBat.to_csv('output/bat_elo.csv')
dfPit.to_csv('output/pit_elo.csv')

# %%
dfBat
# Out:
#      player_id last_name_tx first_name_tx team_id team_tx pos_tx          elo  \
# 0     zimmr001    Zimmerman          Ryan     WAS     WAS     3B   759.860114
# 1     zimmj003   Zimmermann        Jordan     WAS     WAS      P  2531.972876
# 2     wertj001        Werth        Jayson     WAS     WAS     OF   959.340149
# 3     waltz001      Walters          Zach     WAS     WAS     SS  1494.273048
# 4     tracc001        Tracy          Chad     WAS     WAS     3B  1359.538763
# 5     suzuk001       Suzuki          Kurt     WAS     WAS      C  1130.348789
# 9     stras001    Strasburg       Stephen     WAS     WAS      P  2300.412880
# 10    stord001       Storen          Drew     WAS     WAS      P  1787.046072
# 11    stamc001      Stammen         Craig     WAS     WAS      P  1856.236764
# 12    spand001         Span        Denard     WAS     WAS     OF   729.498212
# 13    sorir001      Soriano        Rafael     WAS     WAS      P  1830.433047
# 14    solaj002       Solano      Jhonatan     WAS     WAS      C  1439.366377
# 15    rodrh002    Rodriguez         Henry     WAS     WAS      P  1583.357911
# 17    roart001        Roark        Tanner     WAS     WAS      P  1715.748385
# 18    renda001       Rendon       Anthony     WAS     WAS     3B  1053.329620
# 19    ramow001        Ramos        Wilson     WAS     WAS      C  1152.613934
# 20    peree003        Perez          Eury     WAS     WAS     OF  1488.876672
# 21    ohler001    Ohlendorf          Ross     WAS     WAS      P  1735.793402
# 22    moort002        Moore         Tyler     WAS     WAS     1B  1302.685200
# 23    mayay001         Maya       Yunesky     WAS     WAS      P  1501.034015
# 24    mattr001     Mattheus          Ryan     WAS     WAS      P  1645.093716
# 25    marrc001      Marrero         Chris     WAS     WAS     1B  1480.042398
# 26    lombs002  Lombardozzi         Steve     WAS     WAS     2B  1141.251426
# 27    leons001         Leon         Sandy     WAS     WAS      C  1498.749502
# 28    laroa001      LaRoche          Adam     WAS     WAS     1B   808.225227
# 29    kroli001         Krol           Ian     WAS     WAS      P  1627.888026
# 30    kobej001     Kobernus          Jeff     WAS     WAS     2B  1466.195540
# 31    jordt001       Jordan        Taylor     WAS     WAS      P  1681.689729
# 32    harpb003       Harper         Bryce     WAS     WAS     OF   967.711525
# 33    hared001        Haren           Dan     WAS     WAS      P  2283.095766
# ...        ...          ...           ...     ...     ...    ...          ...
# 1484  rothm001         Roth       Michael     ANA     ANA      P  1539.174211
# 1485  romia001       Romine        Andrew     ANA     ANA     SS  1398.257868
# 1486  richg002     Richards       Garrett     ANA     ANA      P  2093.097574
# 1487  pujoa001       Pujols        Albert     ANA     ANA     1B  1146.835318
# 1488  navae001      Navarro         Efren     ANA     ANA     1B  1499.863244
# 1489  maron001      Maronde          Nick     ANA     ANA      P  1511.035756
# 1490  lowem002         Lowe          Mark     ANA     ANA      P  1521.709430
# 1491  kohnm001         Kohn       Michael     ANA     ANA      P  1678.957518
# 1492  jimel002      Jimenez          Luis     ANA     ANA     3B  1425.318447
# 1493  jepsk001       Jepsen         Kevin     ANA     ANA      P  1609.134432
# 1494  iannc001     Iannetta         Chris     ANA     ANA      C  1220.153555
# 1495  hestj001       Hester          John     ANA     ANA      C  1500.983742
# 1496  hawpb001        Hawpe          Brad     ANA     ANA     OF  1479.877565
# 1497  harrb001       Harris       Brendan     ANA     ANA     SS  1414.189796
# 1498  hanst001       Hanson         Tommy     ANA     ANA      P  1705.978145
# 1499  hamij003     Hamilton          Josh     ANA     ANA     OF   862.705477
# 1500  friee001       Frieri       Ernesto     ANA     ANA      P  1742.979800
# 1501  enrib001      Enright         Barry     ANA     ANA      P  1514.056123
# 1502  couss001      Cousins         Scott     ANA     ANA     OF  1495.716730
# 1503  congh001       Conger          Hank     ANA     ANA      C  1290.773641
# 1504  coelr001       Coello        Robert     ANA     ANA      P  1547.022456
# 1505  carpd002    Carpenter         David     ANA     ANA      P  1497.036368
# 1506  calhk001      Calhoun          Kole     ANA     ANA     OF  1327.828229
# 1507  burns001      Burnett          Sean     ANA     ANA      P  1520.601193
# 1508  buckb002      Buckner         Billy     ANA     ANA      P  1547.345174
# 1509  brasr001      Brasier          Ryan     ANA     ANA      P  1524.251599
# 1510  bourp001      Bourjos         Peter     ANA     ANA     OF  1380.671932
# 1511  boshb001      Boshers         Buddy     ANA     ANA      P  1546.389110
# 1512  blanj001      Blanton           Joe     ANA     ANA      P  1962.904957
# 1513  aybae001        Aybar         Erick     ANA     ANA     SS   923.341919
#
#      nameFirst     nameLast   score
# 0         Ryan    Zimmerman  252.53
# 1       Jordan   Zimmermann    6.25
# 2       Jayson        Werth  252.92
# 3         Zach      Walters    4.75
# 4         Chad        Tracy   35.80
# 5         Kurt       Suzuki   86.08
# 9      Stephen    Strasburg    6.08
# 10        Drew       Storen    0.00
# 11       Craig      Stammen    0.29
# 12      Denard         Span  222.88
# 13      Rafael      Soriano    0.00
# 14    Jhonatan       Solano    7.86
# 15       Henry    Rodriguez    0.00
# 17      Tanner        Roark    3.69
# 18     Anthony       Rendon  135.49
# 19      Wilson        Ramos  135.00
# 20        Eury        Perez    0.48
# 21        Ross    Ohlendorf   -0.46
# 22       Tyler        Moore   50.43
# 23     Yunesky         Maya    0.00
# 24        Ryan     Mattheus    0.00
# 25       Chris      Marrero    1.71
# 26       Steve  Lombardozzi   89.95
# 27       Sandy         Leon   -0.20
# 28        Adam      LaRoche  209.49
# 29         Ian         Krol    0.00
# 30        Jeff     Kobernus    8.98
# 31      Taylor       Jordan    1.56
# 32       Bryce       Harper  205.38
# 33         Dan        Haren    8.11
# ...        ...          ...     ...
# 1484   Michael         Roth    0.00
# 1485    Andrew       Romine   34.75
# 1486   Garrett     Richards    0.00
# 1487    Albert       Pujols  182.34
# 1488     Efren      Navarro    3.01
# 1489      Nick      Maronde    0.00
# 1490      Mark         Lowe    0.00
# 1491   Michael         Kohn    0.00
# 1492      Luis      Jimenez   26.63
# 1493     Kevin       Jepsen    0.00
# 1494     Chris     Iannetta  138.73
# 1495      John       Hester    0.69
# 1496      Brad        Hawpe    6.55
# 1497   Brendan       Harris   30.73
# 1498     Tommy       Hanson    0.00
# 1499      Josh     Hamilton  228.07
# 1500   Ernesto       Frieri    0.00
# 1501     Barry      Enright    0.00
# 1502     Scott      Cousins    0.09
# 1503      Hank       Conger   81.41
# 1504    Robert       Coello    0.00
# 1505     David    Carpenter    0.00
# 1506      Kole      Calhoun   91.85
# 1507      Sean      Burnett    0.00
# 1508     Billy      Buckner    0.00
# 1509      Ryan      Brasier    0.00
# 1510     Peter      Bourjos   61.83
# 1511     Buddy      Boshers    0.00
# 1512       Joe      Blanton    0.48
# 1513     Erick        Aybar  199.12
#
# [1250 rows x 10 columns]

# %%
events = pd.read_csv('data/events_elo.csv')
events.head()
# Out:
#     game_dt    bat_id    pit_id  batter_score  pitcher_score
# 0  20130409  crisc001  wilsc004           0.0            1.0
# 1  20130409  younc004  wilsc004           0.0            1.0
# 2  20130409  lowrj001  wilsc004           1.0            0.0
# 3  20130409  cespy001  wilsc004           1.0            0.0
# 4  20130409  norrd001  wilsc004           1.0            0.0

# %%
dfBat.head()
# Out:
#   player_id last_name_tx first_name_tx team_id team_tx pos_tx          elo  \
# 0  zimmr001    Zimmerman          Ryan     WAS     WAS     3B   759.860114
# 1  zimmj003   Zimmermann        Jordan     WAS     WAS      P  2531.972876
# 2  wertj001        Werth        Jayson     WAS     WAS     OF   959.340149
# 3  waltz001      Walters          Zach     WAS     WAS     SS  1494.273048
# 4  tracc001        Tracy          Chad     WAS     WAS     3B  1359.538763
#
#   nameFirst    nameLast   score
# 0      Ryan   Zimmerman  252.53
# 1    Jordan  Zimmermann    6.25
# 2    Jayson       Werth  252.92
# 3      Zach     Walters    4.75
# 4      Chad       Tracy   35.80

# %%
elo.elo_table.head()
# Out:
#   player_id last_name_tx first_name_tx team_id team_tx pos_tx
# 0  zimmr001    Zimmerman          Ryan     WAS     WAS     3B
# 1  zimmj003   Zimmermann        Jordan     WAS     WAS      P
# 2  wertj001        Werth        Jayson     WAS     WAS     OF
# 3  waltz001      Walters          Zach     WAS     WAS     SS
# 4  tracc001        Tracy          Chad     WAS     WAS     3B

# %%
dfCom.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-23bee840c2fe> in <module>()
# ----> 1 dfCom.head()
#
# NameError: name 'dfCom' is not defined

# %% [markdown]
# ##
